# %%
import torch
import math


dtype = torch.float
device = torch.device("cpu")

# %%
# Hypothesis function H(x) 정의

# x_train = torch.tensor([1, 2, 3])
# y_train = torch.tensor([1, 2, 3])

x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

print(x_train.shape)

W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)
# Out:
# torch.Size([3, 1])

# %%
# Gradient Descent
optimizer = torch.optim.SGD([W, b], lr = 0.01)

# %%
for step in range(2001):

    # H(x) 정의
    hypothesis = x_train * W + b

    # cost function 정의
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    # gradient를 0으로 초기화
    optimizer.zero_grad() 
    # 비용 함수를 미분하여 gradient 계산
    cost.backward() 
    # W와 b를 업데이트
    optimizer.step() 

    # 100번마다 로그 출력
    if step % 100 == 0:
        print(step, cost.item(), W.item(), b.item())
# Out:
# 0 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 100 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 200 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 300 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 400 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 500 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 600 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 700 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 800 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 900 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1000 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1100 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1200 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1300 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1400 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1500 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1600 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1700 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1800 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 1900 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
# 2000 1.2278178473934531e-11 1.9999957084655762 8.701807018951513e-06
